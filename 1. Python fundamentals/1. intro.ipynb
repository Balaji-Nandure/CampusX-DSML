# %%
print("Hello World")

#  print mulitple things
print("Hello", 5, 5.2)

# changing separator
print("Hello", 5, 5.2, sep="/")

# changing end
print("Hello", 5, 5.2, end="|")
# Out:
# Hello World
# Hello 5 5.2
# Hello/5/5.2
# Hello 5 5.2|
