# %%
class Atm:
    def __init__(self):
        self.pin = ''
        self.balance = 0
        print("I will execute at the time of class creation")

    def menu(self):
        user_input = input("""
        Hi how can i help you
        1. create pin
        2. change pin
        3. check balnce
        4. withdraw
        5. exit
        """)

# %%
newATm = Atm()
# Out:
# I will execute first
